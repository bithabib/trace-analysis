# %%
import pandas as pd

file_path = '/home/habib/Desktop/trace-analysis/trace_files/W2K8.TPCC.10-19-2007.12-51-PM.trace-filtered-target'

# %%
# read the trace file
trace = pd.read_csv(file_path, sep=' ')
trace.columns = ['DiskWrite', 'timestamp', 'pid', 'ThreadID', 'IrpPtr', 'ByteOffset', 'IOSize', 'ElapsedTime', 'DiskNum', 'IrpFlags', 'DiskSvcTime', 'delta_time',	'target']
trace.head()
# Out:
#    DiskWrite  timestamp  pid  ThreadID                IrpPtr  ByteOffset
# 0        0.0    4247623  0.0        48  18446738027343121504   276996096  \
# 1        0.0    5288554  0.0        48  18446738027343121504  3201773568
# 2        0.0    5291785  0.0        48  18446738027343121504  3155169280
# 3        0.0    5295691  0.0        48  18446738027343121504  3155156992
# 4        0.0    5301870  0.0        48  18446738027343121504  3161305088
#
#    IOSize  ElapsedTime  DiskNum  IrpFlags  DiskSvcTime  delta_time  target
# 0    1536         4491       16    393283         4491   1000422.0      56
# 1    8192         5322       17    393283         5322   1040931.0      55
# 2    4096         3171       17    393283         3171      3231.0      54
# 3    4096         3876       17    393283         3876      3906.0      53
# 4    8192         5837       16    393283         5837      6179.0      52
