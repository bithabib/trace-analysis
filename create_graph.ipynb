# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#  read json file into a pandas dataframe
s1_seq_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/seq_trace.log.json')
s1_uniform_random_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/uniform_random_1598512.json')
s1_zipf_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/zipf_trace.log.json')


sequential_op_10_df = pd.read_json('graph_data/OP10__05_29_2024/seq_trace.log_waf.json')
uniform_random_op_10_df = pd.read_json('graph_data/OP10__05_29_2024/uniform_random_1598512_waf.json')
zipf_op_10_df = pd.read_json('graph_data/OP10__05_29_2024/zipf_trace.log_waf.json')
sequential_op_20_df = pd.read_json('graph_data/OP20__05_29_2024/seq_trace.log_waf.json')
uniform_random_op_20_df = pd.read_json('graph_data/OP20__05_29_2024/uniform_random_1598512_waf.json')
zipf_op_20_df = pd.read_json('graph_data/OP20__05_29_2024/zipf_trace.log_waf.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #  read json file into a pandas dataframe
# ----> 2 sequential_op_10_df = pd.read_json('graph_data/OP10__05_29_2024/seq_trace.log_waf.json')
#       3 uniform_random_op_10_df = pd.read_json('graph_data/OP10__05_29_2024/uniform_random_1598512_waf.json')
#       4 zipf_op_10_df = pd.read_json('graph_data/OP10__05_29_2024/zipf_trace.log_waf.json')
#
# File ~/jupyter/lib/python3.8/site-packages/pandas/io/json/_json.py:760, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     757 if convert_axes is None and orient != "table":
#     758     convert_axes = True
# --> 760 json_reader = JsonReader(
#     761     path_or_buf,
# ...

# %%
# plot the data and show the max value of waf for each trace

fig, ax = plt.subplots()
ax.set_title('WAF vs Time')
ax.set_xlabel('Sequence Number')
ax.set_ylabel('WAF')
sequential_op_10_df.plot(y='waf', ax=ax, label='Sequential OP-10='+str(round(sequential_op_10_df['waf'].max(),2)))
uniform_random_op_10_df.plot(y='waf', ax=ax, label='Uniform Random OP-10='+str(round(uniform_random_op_10_df['waf'].max(),2)))
zipf_op_10_df.plot(y='waf', ax=ax, label='Zipf OP-10='+str(round(zipf_op_10_df['waf'].max(),2)))
sequential_op_20_df.plot(y='waf', ax=ax, label='Sequential OP-20='+str(round(sequential_op_20_df['waf'].max(),2)))
uniform_random_op_20_df.plot(y='waf', ax=ax, label='Uniform Random OP-20='+str(round(uniform_random_op_20_df['waf'].max(),2)))
zipf_op_20_df.plot(y='waf', ax=ax, label='Zipf OP-20='+str(round(zipf_op_20_df['waf'].max(),2)))
plt.savefig('waf_vs_time.png')
plt.show()
# download the plot

# %%
#  read json file into a pandas dataframe
pareto_random_op_5_cum_time_df = pd.read_json('trace_files/graph_data/op_5_65_t/pareto_trace.log_cummalative_time_per_packet.json')
pareto_random_op_10_cum_time_df = pd.read_json('trace_files/graph_data/op_10_60_t/pareto_trace.log_cummalative_time_per_packet.json')
pareto_random_op_15_cum_time_df = pd.read_json('trace_files/graph_data/op_15_55_t/pareto_trace.log_cummalative_time_per_packet.json')
pareto_random_op_20_cum_time_df = pd.read_json('trace_files/graph_data/op_20_50_t/pareto_trace.log_cummalative_time_per_packet.json')
sequential_op_5_cum_time_df = pd.read_json('trace_files/graph_data/op_5_65_t/seq_trace.log_cummalative_time_per_packet.json')
sequential_op_10_cum_time_df = pd.read_json('trace_files/graph_data/op_10_60_t/seq_trace.log_cummalative_time_per_packet.json')
sequential_op_15_cum_time_df = pd.read_json('trace_files/graph_data/op_15_55_t/seq_trace.log_cummalative_time_per_packet.json')
sequential_op_20_cum_time_df = pd.read_json('trace_files/graph_data/op_20_50_t/seq_trace.log_cummalative_time_per_packet.json')

# %%
# plot the data and show the max value of waf for each trace

fig, ax = plt.subplots()
ax.set_title('Cumulative Time vs Write Packet')
ax.set_xlabel('Write Packet')
ax.set_ylabel('Cumulative Time')
pareto_random_op_5_cum_time_df.plot(y='time', ax=ax, label='pareto_random_op_5='+str(round(pareto_random_op_5_cum_time_df['time'].max(),2)))
pareto_random_op_10_cum_time_df.plot(y='time', ax=ax, label='pareto_random_op_10='+str(round(pareto_random_op_10_cum_time_df['time'].max(),2)))
pareto_random_op_15_cum_time_df.plot(y='time', ax=ax, label='pareto_random_op_15='+str(round(pareto_random_op_15_cum_time_df['time'].max(),2)))
pareto_random_op_20_cum_time_df.plot(y='time', ax=ax, label='pareto_random_op_20='+str(round(pareto_random_op_20_cum_time_df['time'].max(),2)))
sequential_op_5_cum_time_df.plot(y='time', ax=ax, label='sequential_op_5='+str(round(sequential_op_5_cum_time_df['time'].max(),2)))
sequential_op_10_cum_time_df.plot(y='time', ax=ax, label='sequential_op_10='+str(round(sequential_op_10_cum_time_df['time'].max(),2)))
sequential_op_15_cum_time_df.plot(y='time', ax=ax, label='sequential_op_15='+str(round(sequential_op_15_cum_time_df['time'].max(),2)))
sequential_op_20_cum_time_df.plot(y='time', ax=ax, label='sequential_op_20='+str(round(sequential_op_20_cum_time_df['time'].max(),2)))
plt.show()

# %%
# Generate Erase Count vs Each block for each trace
#  read json file into a pandas dataframe
seq_trace_df = pd.read_json('graph_data/seq_trace.log.json')
uniform_random_trace_df = pd.read_json('graph_data/uniform_random_trace.log.json')
zipf_trace_df = pd.read_json('graph_data/zipf_trace.log.json')
# remove first column which is the block number replace it with the index
zipf_erase_count = zipf_trace_df.iloc[6]
zipf_erase_count = zipf_erase_count.reset_index(drop=True)
# add name of the column to the dataframe
zipf_erase_count = zipf_erase_count.to_frame()
zipf_erase_count.columns = ['erase_count']
zipf_erase_count
# Out:
#      erase_count
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 4795           0
# 4796           0
# 4797           0
# 4798           0
# 4799           0
#
# [4800 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import pandas as pd

# Read JSON files into pandas dataframes
seq_trace_df = pd.read_json('graph_data/seq_trace.log.json')
uniform_random_trace_df = pd.read_json('graph_data/uniform_random_trace.log.json')
zipf_trace_df = pd.read_json('graph_data/zipf_trace.log.json')

# Extract the erase count data
seq_erase_count = seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
uniform_random_erase_count = uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
zipf_erase_count = zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# Calculate mean and standard deviation
seq_mean = np.mean(seq_erase_count['erase_count'])
seq_std_dev = np.std(seq_erase_count['erase_count'])
uni_mean = np.mean(uniform_random_erase_count['invalid_pages'])
uni_std_dev = np.std(uniform_random_erase_count['erase_count'])
zipf_mean = np.mean(zipf_erase_count['erase_count'])
zipf_std_dev = np.std(zipf_erase_count['erase_count'])

# Create the plot
plt.figure(figsize=(15, 10))

# Plot for sequential erase count
x_seq = np.linspace(seq_mean - 3*seq_std_dev, seq_mean + 3*seq_std_dev, 100)
bell_curve_seq = stats.norm.pdf(x_seq, seq_mean, seq_std_dev)
sns.histplot(seq_erase_count['erase_count'], bins=10, kde=False, stat='density', color='blue', alpha=0.6, label='Sequential Erase Count')
plt.plot(x_seq, bell_curve_seq, color='blue')

# Plot for uniform random erase count
x_uni = np.linspace(uni_mean - 3*uni_std_dev, uni_mean + 3*uni_std_dev, 100)
bell_curve_uni = stats.norm.pdf(x_uni, uni_mean, uni_std_dev)
sns.histplot(uniform_random_erase_count['erase_count'], bins=10, kde=False, stat='density', color='green', alpha=0.6, label='Uniform Random Erase Count')
plt.plot(x_uni, bell_curve_uni, color='green')

# Plot for zipf erase count
x_zipf = np.linspace(zipf_mean - 3*zipf_std_dev, zipf_mean + 3*zipf_std_dev, 100)
bell_curve_zipf = stats.norm.pdf(x_zipf, zipf_mean, zipf_std_dev)
sns.histplot(zipf_erase_count['erase_count'], bins=10, kde=False, stat='density', color='red', alpha=0.6, label='Zipf Erase Count')
plt.plot(x_zipf, bell_curve_zipf, color='red')

# Add title and labels
plt.title('Histogram with Bell Curves for Different Traces')
plt.xlabel('Erase Count')
plt.ylabel('Density')

# Display summary statistics on the plot
plt.figtext(0.15, 0.8, f'Seq Mean: {seq_mean:.2f}, Seq Std Dev: {seq_std_dev:.2f}\n'
                        f'Uni Mean: {uni_mean:.2f}, Uni Std Dev: {uni_std_dev:.2f}\n'
                        f'Zipf Mean: {zipf_mean:.2f}, Zipf Std Dev: {zipf_std_dev:.2f}', 
            fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Add legend
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read JSON files into pandas dataframes
seq_trace_df = pd.read_json('graph_data/seq_trace.log.json')
uniform_random_trace_df = pd.read_json('graph_data/uniform_random_trace.log.json')
zipf_trace_df = pd.read_json('graph_data/zipf_trace.log.json')

# Extract the erase count data
seq_erase_count = seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
uniform_random_erase_count = uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
zipf_erase_count = zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# Add a column to indicate the trace type
seq_erase_count['trace_type'] = 'Sequential'
uniform_random_erase_count['trace_type'] = 'Uniform Random'
zipf_erase_count['trace_type'] = 'Zipf'

# Combine the dataframes
combined_df = pd.concat([seq_erase_count, uniform_random_erase_count, zipf_erase_count])

# Create the box plot
plt.figure(figsize=(12, 8))
sns.boxplot(x='trace_type', y='erase_count', data=combined_df, palette=['blue', 'green', 'red'])

# Add title and labels
plt.title('Box Plot of Erase Counts for Different Traces')
plt.xlabel('Trace Type')
plt.ylabel('Erase Count')

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_88673/1747904493.py:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='trace_type', y='erase_count', data=combined_df, palette=['blue', 'green', 'red'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import pandas as pd

# Read JSON files into pandas dataframes
sequential_op_10_df = pd.read_json('graph_data/S1_OP10__05_29_2024/seq_trace.log.json')
uniform_random_op_10_df = pd.read_json('graph_data/S1_OP10__05_29_2024/uniform_random_1598512.json')
zipf_op_10_df = pd.read_json('graph_data/S1_OP10__05_29_2024/zipf_trace.log.json')

# Extract the invalid pages 
seq_invalid_pages = sequential_op_10_df.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
uniform_random_invalid_pages = uniform_random_op_10_df.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')
zipf_invalid_pages = zipf_op_10_df.iloc[4].reset_index(drop=True).to_frame(name='invalid_pages')

# Calculate mean and standard deviation
seq_mean = np.mean(seq_invalid_pages['invalid_pages'])
seq_std_dev = np.std(seq_invalid_pages['invalid_pages'])
uni_mean = np.mean(uniform_random_invalid_pages['invalid_pages'])
uni_std_dev = np.std(uniform_random_invalid_pages['invalid_pages'])
zipf_mean = np.mean(zipf_invalid_pages['invalid_pages'])
zipf_std_dev = np.std(zipf_invalid_pages['invalid_pages'])
plt.rcParams.update({'font.size': 16})
# Create the plot
plt.figure(figsize=(15, 10))

# Plot for sequential invalid pages
x_seq = np.linspace(seq_mean - 3*seq_std_dev, seq_mean + 3*seq_std_dev, 100)
bell_curve_seq = stats.norm.pdf(x_seq, seq_mean, seq_std_dev)
sns.histplot(seq_invalid_pages['invalid_pages'], bins=10, kde=False, stat='density', color='blue', alpha=0.6, label='Sequential Invalid Pages')
plt.plot(x_seq, bell_curve_seq, color='blue')

# Plot for uniform random invalid pages
x_uni = np.linspace(uni_mean - 3*uni_std_dev, uni_mean + 3*uni_std_dev, 100)
bell_curve_uni = stats.norm.pdf(x_uni, uni_mean, uni_std_dev)
sns.histplot(uniform_random_invalid_pages['invalid_pages'], bins=10, kde=False, stat='density', color='green', alpha=0.6, label='Uniform Random Invalid Pages')
plt.plot(x_uni, bell_curve_uni, color='green')

# Plot for zipf invalid pages
x_zipf = np.linspace(zipf_mean - 3*zipf_std_dev, zipf_mean + 3*zipf_std_dev, 100)
bell_curve_zipf = stats.norm.pdf(x_zipf, zipf_mean, zipf_std_dev)
sns.histplot(zipf_invalid_pages['invalid_pages'], bins=10, kde=False, stat='density', color='red', alpha=0.6, label='Zipf Invalid Pages')
plt.plot(x_zipf, bell_curve_zipf, color='red')

# Add title and labels
plt.title('Histogram with Bell Curves for Different Workloads')
plt.xlabel('Invalid Pages')
plt.ylabel('Density')

# Display summary statistics on the plot
plt.figtext(0.15, 0.8, f'Seq Mean: {seq_mean:.2f}, Seq Std Dev: {seq_std_dev:.2f}\n'
                        f'Uni Mean: {uni_mean:.2f}, Uni Std Dev: {uni_std_dev:.2f}\n'
                        f'Zipf Mean: {zipf_mean:.2f}, Zipf Std Dev: {zipf_std_dev:.2f}', 
            fontsize=14, bbox=dict(facecolor='white', alpha=0.5))

# Add legend
plt.legend()

# %%
# Waf Comparison with EaynaSSDSim vs FTLSim
# EaynaSSDSim  WAF:
# Pareto: 3.2675830954055116
# Sequential: 1.3467720292791623
# Zipf: 1.0737934481587295
# U_random: 2.394273549400943
# FTLSim:
# Pareto: 3.942031524080965
# Sequential: 1.7764095179172534
# Zipf: 1.1208162683143337
# U_random: 3.1472081535828322

# Draw a column graph to show the comparison
import matplotlib.pyplot as plt
import numpy as np

# Data
waf_eayna = [3.2675830954055116, 1.3467720292791623, 1.0737934481587295, 2.394273549400943]
waf_ftl = [3.942031524080965, 1.7764095179172534, 1.1208162683143337, 3.1472081535828322]

# Labels
labels = ['Pareto', 'Sequential', 'Zipf', 'Uniform Random']

# Width of the bars
barWidth = 0.35

# Set position of bar on X axis
r1 = np.arange(len(waf_eayna))
r2 = [x + barWidth for x in r1]

# Create the plot
plt.figure(figsize=(12, 8))
# Plot the bars with light color for EaynaSSDSim and dark color for FTLSim
plt.bar(r1, waf_eayna, color='skyblue', width=barWidth, edgecolor='grey', label='EaynaSSDSim')
plt.bar(r2, waf_ftl, color='salmon', width=barWidth, edgecolor='grey', label='FTLSim')

# Add xticks on the middle of the group bars
plt.xlabel('Trace Type', fontweight='bold')
plt.ylabel('WAF', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(waf_eayna))], labels)

# Add title
plt.title('WAF Comparison between EaynaSSDSim and FTLSim')

# Add legend
plt.legend()
plt.savefig('waf_comparison.png')
# Display the plot
plt.show()
# save the plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
waf_eayna = [3.2675830954055116, 1.3467720292791623, 1.0737934481587295, 2.394273549400943]
waf_ftl = [3.942031524080965, 1.7764095179172534, 1.1208162683143337, 3.1472081535828322]

# Labels
labels = ['Pareto', 'Sequential', 'Zipf', 'Uniform Random']

# Width of the bars
barWidth = 0.35

# Set position of bar on X axis
r1 = np.arange(len(waf_eayna))
r2 = [x + barWidth for x in r1]

def plot_dotted_bar(x, heights, color, width, dot_spacing=0.1):
    for x_pos, height in zip(x, heights):
        y_dots = np.arange(0, height, dot_spacing)
        x_dots = np.arange(x_pos - width / 2, x_pos + width / 2, dot_spacing)
        X, Y = np.meshgrid(x_dots, y_dots)
        plt.scatter(X, Y, color=color, s=10)  # s=10 controls the size of the dots

# Create the plot
plt.figure(figsize=(12, 8))

# Plot the bars made of dots
plot_dotted_bar(r1, waf_eayna, color='blue', width=barWidth)
plot_dotted_bar(r2, waf_ftl, color='red', width=barWidth)

# Add xticks on the middle of the group bars
plt.xlabel('Trace Type', fontweight='bold')
plt.ylabel('WAF', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(waf_eayna))], labels)

# Add title
plt.title('WAF Comparison between EaynaSSDSim and FTLSim')

# Add legend
plt.legend(['EaynaSSDSim', 'FTLSim'], loc='upper right')

# Save the plot
plt.savefig('waf_comparison.png')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import pandas as pd

# Read JSON files into pandas dataframes
seq_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/seq_trace.log.json')
uniform_random_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/uniform_random_1598512.json')
zipf_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/zipf_trace.log.json')

# Extract the erase count data
seq_erase_count = seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
uniform_random_erase_count = uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
zipf_erase_count = zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# Calculate mean and standard deviation
seq_mean = np.mean(seq_erase_count['erase_count'])
seq_std_dev = np.std(seq_erase_count['erase_count'])
uni_mean = np.mean(uniform_random_erase_count['erase_count'])
uni_std_dev = np.std(uniform_random_erase_count['erase_count'])
zipf_mean = np.mean(zipf_erase_count['erase_count'])
zipf_std_dev = np.std(zipf_erase_count['erase_count'])

# Create the plot
plt.figure(figsize=(15, 10))

# Plot for sequential erase count
x_seq = np.linspace(seq_mean - 3*seq_std_dev, seq_mean + 3*seq_std_dev, 100)
bell_curve_seq = stats.norm.pdf(x_seq, seq_mean, seq_std_dev)
sns.histplot(seq_erase_count['erase_count'], bins=10, kde=False, stat='density', color='blue', alpha=0.6, label='Sequential Erase Count')
plt.plot(x_seq, bell_curve_seq, color='blue')

# Plot for uniform random erase count
x_uni = np.linspace(uni_mean - 3*uni_std_dev, uni_mean + 3*uni_std_dev, 100)
bell_curve_uni = stats.norm.pdf(x_uni, uni_mean, uni_std_dev)
sns.histplot(uniform_random_erase_count['erase_count'], bins=10, kde=False, stat='density', color='green', alpha=0.6, label='Uniform Random Erase Count')
plt.plot(x_uni, bell_curve_uni, color='green')

# Plot for zipf erase count
x_zipf = np.linspace(zipf_mean - 3*zipf_std_dev, zipf_mean + 3*zipf_std_dev, 100)
bell_curve_zipf = stats.norm.pdf(x_zipf, zipf_mean, zipf_std_dev)
sns.histplot(zipf_erase_count['erase_count'], bins=10, kde=False, stat='density', color='red', alpha=0.6, label='Zipf Erase Count')
plt.plot(x_zipf, bell_curve_zipf, color='red')

# Add title and labels
plt.title('Histogram with Bell Curves for Different Traces')
plt.xlabel('Erase Count')
plt.ylabel('Density')

# Display summary statistics on the plot
plt.figtext(0.15, 0.8, f'Seq Mean: {seq_mean:.2f}, Seq Std Dev: {seq_std_dev:.2f}\n'
                        f'Uni Mean: {uni_mean:.2f}, Uni Std Dev: {uni_std_dev:.2f}\n'
                        f'Zipf Mean: {zipf_mean:.2f}, Zipf Std Dev: {zipf_std_dev:.2f}', 
            fontsize=12, bbox=dict(facecolor='white', alpha=0.5))

# Add legend
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import pandas as pd

# Read JSON files into pandas dataframes
seq_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_seq_trace.log.json')
uniform_random_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_uniform_random_1598512.json')
zipf_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_zipf_trace.log.json')

# Extract the erase count data
seq_erase_count = seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
uniform_random_erase_count = uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
zipf_erase_count = zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# Calculate mean and standard deviation
seq_mean = np.mean(seq_erase_count['erase_count'])
seq_std_dev = np.std(seq_erase_count['erase_count'])
uni_mean = np.mean(uniform_random_erase_count['erase_count'])
uni_std_dev = np.std(uniform_random_erase_count['erase_count'])
zipf_mean = np.mean(zipf_erase_count['erase_count'])
zipf_std_dev = np.std(zipf_erase_count['erase_count'])
# increase the size of text 
plt.rcParams.update({'font.size': 16})
# Create the plot
plt.figure(figsize=(15, 10))

# Plot for sequential erase count
x_seq = np.linspace(seq_mean - 3*seq_std_dev, seq_mean + 3*seq_std_dev, 100)
bell_curve_seq = stats.norm.pdf(x_seq, seq_mean, seq_std_dev)
sns.histplot(seq_erase_count['erase_count'], bins=10, kde=False, stat='density', color='blue', alpha=0.6, label='Sequential Erase Count')
plt.plot(x_seq, bell_curve_seq, color='blue')

# Plot for uniform random erase count
x_uni = np.linspace(uni_mean - 3*uni_std_dev, uni_mean + 3*uni_std_dev, 100)
bell_curve_uni = stats.norm.pdf(x_uni, uni_mean, uni_std_dev)
sns.histplot(uniform_random_erase_count['erase_count'], bins=10, kde=False, stat='density', color='green', alpha=0.6, label='Uniform Random Erase Count')
plt.plot(x_uni, bell_curve_uni, color='green')

# Plot for zipf erase count
x_zipf = np.linspace(zipf_mean - 3*zipf_std_dev, zipf_mean + 3*zipf_std_dev, 100)
bell_curve_zipf = stats.norm.pdf(x_zipf, zipf_mean, zipf_std_dev)
sns.histplot(zipf_erase_count['erase_count'], bins=10, kde=False, stat='density', color='red', alpha=0.6, label='Zipf Erase Count')
plt.plot(x_zipf, bell_curve_zipf, color='red')

# Add title and labels
plt.title('Histogram with Bell Curves for Different Workloads')
plt.xlabel('Erase Count')
plt.ylabel('Density')

# Display summary statistics on the plot
plt.figtext(0.15, 0.8, f'Seq Mean: {seq_mean:.2f}, Seq Std Dev: {seq_std_dev:.2f}\n'
                        f'Uni Mean: {uni_mean:.2f}, Uni Std Dev: {uni_std_dev:.2f}\n'
                        f'Zipf Mean: {zipf_mean:.2f}, Zipf Std Dev: {zipf_std_dev:.2f}', 
            fontsize=16, bbox=dict(facecolor='white', alpha=0.5))

# Add legend
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import pandas as pd

# Read JSON files into pandas dataframes
s1_seq_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/seq_trace.log.json')
s1_uniform_random_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/uniform_random_1598512.json')
s1_zipf_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/zipf_trace.log.json')

# Extract the erase count data
s1_seq_erase_count = s1_seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s1_uniform_random_erase_count = s1_uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s1_zipf_erase_count = s1_zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# remove all 0 values 
s1_seq_erase_count = s1_seq_erase_count[s1_seq_erase_count['erase_count'] > 0]
s1_uniform_random_erase_count = s1_uniform_random_erase_count[s1_uniform_random_erase_count['erase_count'] > 0]
s1_zipf_erase_count = s1_zipf_erase_count[s1_zipf_erase_count['erase_count'] > 0]


# Read JSON files into pandas dataframes
s2_seq_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_seq_trace.log.json')
s2_uniform_random_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_uniform_random_1598512.json')
s2_zipf_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_zipf_trace.log.json')

# Extract the erase count data
s2_seq_erase_count = s2_seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s2_uniform_random_erase_count = s2_uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s2_zipf_erase_count = s2_zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# remove all 0 values
s2_seq_erase_count = s2_seq_erase_count[s2_seq_erase_count['erase_count'] > 0]
s2_uniform_random_erase_count = s2_uniform_random_erase_count[s2_uniform_random_erase_count['erase_count'] > 0]
s2_zipf_erase_count = s2_zipf_erase_count[s2_zipf_erase_count['erase_count'] > 0]


# create bar chart  for erase count for s1 sequential and s2 sequenatila x axis count y axis erase count
# Create the plot
plt.figure(figsize=(15, 10))

# Plot for sequential erase count
x_seq = np.arange(len(s1_seq_erase_count))
plt.bar(x_seq, s1_seq_erase_count['erase_count'], color='blue', alpha=0.6, label='S1 Sequential Erase Count')

# Plot for sequential erase count
x_seq = np.arange(len(s2_seq_erase_count))
plt.bar(x_seq, s2_seq_erase_count['erase_count'], color='red', alpha=0.3, label='S2 Sequential Erase Count')

# Add title and labels
plt.title('Erase Count for S1 and S2 Sequential Traces')
plt.xlabel('Block Number')
plt.ylabel('Erase Count')

# Add legend
plt.legend()

plt.show()


# create a line chart for erase count for s1 sequential and s2 sequential x axis count y axis erase count
# Create the plot
plt.figure(figsize=(15, 10))

# Plot for sequential erase count
x_seq = np.arange(len(s1_seq_erase_count))
plt.plot(x_seq, s1_seq_erase_count['erase_count'], color='blue', alpha=0.6, label='S1 Sequential Erase Count')

# Plot for sequential erase count
x_seq = np.arange(len(s2_seq_erase_count))
plt.plot(x_seq, s2_seq_erase_count['erase_count'], color='red', alpha=0.3, label='S2 Sequential Erase Count')

# Add title and labels
plt.title('Erase Count for S1 and S2 Sequential Traces')
plt.xlabel('Block Number')
plt.ylabel('Erase Count')

# Add legend
plt.legend()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq

# Read JSON files into pandas dataframes
s1_seq_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/seq_trace.log.json')
s1_uniform_random_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/uniform_random_1598512.json')
s1_zipf_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/zipf_trace.log.json')

# Extract the erase count data
s1_seq_erase_count = s1_seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s1_uniform_random_erase_count = s1_uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s1_zipf_erase_count = s1_zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# remove all 0 values 
s1_seq_erase_count = s1_seq_erase_count[s1_seq_erase_count['erase_count'] > 0]
s1_uniform_random_erase_count = s1_uniform_random_erase_count[s1_uniform_random_erase_count['erase_count'] > 0]
s1_zipf_erase_count = s1_zipf_erase_count[s1_zipf_erase_count['erase_count'] > 0]


# Read JSON files into pandas dataframes
s2_seq_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_seq_trace.log.json')
s2_uniform_random_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_uniform_random_1598512.json')
s2_zipf_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_zipf_trace.log.json')

# Extract the erase count data
s2_seq_erase_count = s2_seq_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s2_uniform_random_erase_count = s2_uniform_random_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')
s2_zipf_erase_count = s2_zipf_trace_df.iloc[6].reset_index(drop=True).to_frame(name='erase_count')

# remove all 0 values
s2_seq_erase_count = s2_seq_erase_count[s2_seq_erase_count['erase_count'] > 0]
s2_uniform_random_erase_count = s2_uniform_random_erase_count[s2_uniform_random_erase_count['erase_count'] > 0]
s2_zipf_erase_count = s2_zipf_erase_count[s2_zipf_erase_count['erase_count'] > 0]

# Number of samples
N_s1_seq = len(s1_zipf_erase_count)
# Sample spacing (assuming uniform spacing)
T = 1.0

# Compute the FFT for both S1 and S2
yf_s1 = fft(s1_zipf_erase_count)
yf_s2 = fft(s2_zipf_erase_count)
xf = fftfreq(N, T)[:N//2]

# Plot the FFT results
plt.figure(figsize=(14, 7))

# S1 FFT plot
plt.subplot(2, 1, 1)
plt.plot(xf, 2.0/N * np.abs(yf_s1[:N//2]), label='S1 Fourier Transform')
plt.title('Fourier Transform of S1 Erase Count')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.legend()

# S2 FFT plot
plt.subplot(2, 1, 2)
plt.plot(xf, 2.0/N * np.abs(yf_s2[:N//2]), label='S2 Fourier Transform', color='orange')
plt.title('Fourier Transform of S2 Erase Count')
plt.xlabel('Frequency')
plt.ylabel('Amplitude')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft, fftfreq


# Read JSON files into pandas dataframes
s1_seq_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/seq_trace.log.json')
s1_uniform_random_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/uniform_random_1598512.json')
s1_zipf_trace_df = pd.read_json('graph_data/S1_OP10__05_29_2024/zipf_trace.log.json')

# Extract the erase count data
s1_seq_invalid_page_count = s1_seq_trace_df.iloc[4].reset_index(drop=True).to_frame(name='erase_count')
s1_uniform_random_invalid_page_count = s1_uniform_random_trace_df.iloc[4].reset_index(drop=True).to_frame(name='erase_count')
s1_zipf_invalid_page_count = s1_zipf_trace_df.iloc[4].reset_index(drop=True).to_frame(name='erase_count')

# remove all 0 values 
s1_seq_invalid_page_count = s1_seq_invalid_page_count[s1_seq_invalid_page_count['erase_count'] > 0]
s1_uniform_random_invalid_page_count = s1_uniform_random_invalid_page_count[s1_uniform_random_invalid_page_count['erase_count'] > 0]
s1_zipf_invalid_page_count = s1_zipf_invalid_page_count[s1_zipf_invalid_page_count['erase_count'] > 0]


# Read JSON files into pandas dataframes
s2_seq_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_seq_trace.log.json')
s2_uniform_random_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_uniform_random_1598512.json')
s2_zipf_trace_df = pd.read_json('graph_data/S2_OP10__05_29_2024/s2_zipf_trace.log.json')

# Extract the erase count data
s2_seq_ivalid_page_count = s2_seq_trace_df.iloc[4].reset_index(drop=True).to_frame(name='erase_count')
s2_uniform_random_invalid_page_count = s2_uniform_random_trace_df.iloc[4].reset_index(drop=True).to_frame(name='erase_count')
s2_zipf_invalid_page_count = s2_zipf_trace_df.iloc[4].reset_index(drop=True).to_frame(name='erase_count')

# remove all 0 values
s2_seq_ivalid_page_count = s2_seq_ivalid_page_count[s2_seq_ivalid_page_count['erase_count'] > 0]
s2_uniform_random_invalid_page_count = s2_uniform_random_invalid_page_count[s2_uniform_random_invalid_page_count['erase_count'] > 0]
s2_zipf_invalid_page_count = s2_zipf_invalid_page_count[s2_zipf_invalid_page_count['erase_count'] > 0]

# Number of samples
N = len(s2_uniform_random_invalid_page_count)
# Sample spacing (assuming uniform spacing)
T = 1.0

# Compute the FFT for seq, random , zipf both S1 and S2
seq_yf_s1 = fft(s1_seq_invalid_page_count)
seq_yf_s2 = fft(s2_seq_ivalid_page_count)
uniform_random_yf_s1 = fft(s1_uniform_random_invalid_page_count)
uniform_random_yf_s2 = fft(s2_uniform_random_invalid_page_count)
zipf_yf_s1 = fft(s1_zipf_invalid_page_count)
zipf_yf_s2 = fft(s2_zipf_invalid_page_count)
xf = fftfreq(N, T)[:N//2]

# find the average amplitude of the fft for S1 and S2 for all traces
average_amplitude_seq_s1 = np.mean(np.abs(seq_yf_s1[:N//2]))
average_amplitude_seq_s2 = np.mean(np.abs(seq_yf_s2[:N//2]))
average_amplitude_uniform_random_s1 = np.mean(np.abs(uniform_random_yf_s1[:N//2]))
average_amplitude_uniform_random_s2 = np.mean(np.abs(uniform_random_yf_s2[:N//2]))
average_amplitude_zipf_s1 = np.mean(np.abs(zipf_yf_s1[:N//2]))
average_amplitude_zipf_s2 = np.mean(np.abs(zipf_yf_s2[:N//2]))


# find the maximum amplitude of the fft for S1 and S2 for all traces
max_amplitude_seq_s1 = np.max(np.abs(seq_yf_s1[:N//2]))
max_amplitude_seq_s2 = np.max(np.abs(seq_yf_s2[:N//2]))
max_amplitude_uniform_random_s1 = np.max(np.abs(uniform_random_yf_s1[:N//2]))
max_amplitude_uniform_random_s2 = np.max(np.abs(uniform_random_yf_s2[:N//2]))
max_amplitude_zipf_s1 = np.max(np.abs(zipf_yf_s1[:N//2]))
max_amplitude_zipf_s2 = np.max(np.abs(zipf_yf_s2[:N//2]))

print(f'Maximum Amplitude of S1 Sequential: {max_amplitude_seq_s1}')
print(f'Maximum Amplitude of S2 Sequential: {max_amplitude_seq_s2}')
print(f'Maximum Amplitude of S1 Uniform Random: {max_amplitude_uniform_random_s1}')
print(f'Maximum Amplitude of S2 Uniform Random: {max_amplitude_uniform_random_s2}')
print(f'Maximum Amplitude of S1 Zipf: {max_amplitude_zipf_s1}')
print(f'Maximum Amplitude of S2 Zipf: {max_amplitude_zipf_s2}')


print(f'Average Amplitude of S1 Sequential: {average_amplitude_seq_s1}')
print(f'Average Amplitude of S2 Sequential: {average_amplitude_seq_s2}')
print(f'Average Amplitude of S1 Uniform Random: {average_amplitude_uniform_random_s1}')
print(f'Average Amplitude of S2 Uniform Random: {average_amplitude_uniform_random_s2}')
print(f'Average Amplitude of S1 Zipf: {average_amplitude_zipf_s1}')
print(f'Average Amplitude of S2 Zipf: {average_amplitude_zipf_s2}')

# Find the deviation of fft for S1 and S2 for all traces two decimal places
deviation_seq_s1 = np.std(2.0/N * np.abs(seq_yf_s1[:N//2])).round(6)
deviation_seq_s2 = np.std(2.0/N * np.abs(seq_yf_s2[:N//2])).round(6)
deviation_uniform_random_s1 = np.std(2.0/N * np.abs(uniform_random_yf_s1[:N//2])).round(6)
deviation_uniform_random_s2 = np.std(2.0/N * np.abs(uniform_random_yf_s2[:N//2])).round(6)
deviation_zipf_s1 = np.std(np.abs(2.0/N * zipf_yf_s1[:N//2])).round(6)
deviation_zipf_s2 = np.std(np.abs(2.0/N * zipf_yf_s2[:N//2])).round(6)

print(f'Deviation of S1 Sequential: {deviation_seq_s1}')
print(f'Deviation of S2 Sequential: {deviation_seq_s2}')
print(f'Deviation of S1 Uniform Random: {deviation_uniform_random_s1}')
print(f'Deviation of S2 Uniform Random: {deviation_uniform_random_s2}')
print(f'Deviation of S1 Zipf: {deviation_zipf_s1}')
print(f'Deviation of S2 Zipf: {deviation_zipf_s2}')


# Plot the FFT results
# increase the text size
plt.rcParams.update({'font.size': 16})
plt.figure(figsize=(14, 7))

# S1 FFT plot
plt.subplot(2, 1, 1)
plt.plot(xf, 2.0/N * np.abs(seq_yf_s1[:N//2]), label='Sequential Std Dev in amplitude: '+ str(deviation_seq_s1), color='blue')
plt.plot(xf, 2.0/N * np.abs(uniform_random_yf_s1[:N//2]), label='Uniform Random Std Dev in amplitude: '+ str(deviation_uniform_random_s1), color='orange')
plt.plot(xf, 2.0/N * np.abs(zipf_yf_s1[:N//2]), label='Zipf Std Dev in amplitude: '+ str(deviation_zipf_s1), color='green')

plt.title('Fourier Transform of S1 Erase Count')
plt.xlabel('Frequency of block')
plt.ylabel('Amplitude of erase count')
plt.legend()

# S2 FFT plot
plt.subplot(2, 1, 2)
plt.plot(xf, 2.0/N * np.abs(seq_yf_s2[:N//2]), label='Sequential Std Dev in amplitude: '+ str(deviation_seq_s2), color='blue')
plt.plot(xf, 2.0/N * np.abs(uniform_random_yf_s2[:N//2]), label='Uniform Random Std Dev in amplitude: '+ str(deviation_uniform_random_s2), color='orange')
plt.plot(xf, 2.0/N * np.abs(zipf_yf_s2[:N//2]), label='Zipf Std Dev in amplitude: '+ str(deviation_zipf_s2), color='green')

plt.title('Fourier Transform of S2 Erase Count')
plt.xlabel('Frequency of block')
plt.ylabel('Amplitude of erase count')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Maximum Amplitude of S1 Sequential: 139.0
# Maximum Amplitude of S2 Sequential: 139.0
# Maximum Amplitude of S1 Uniform Random: 166.0
# Maximum Amplitude of S2 Uniform Random: 108.0
# Maximum Amplitude of S1 Zipf: 220.0
# Maximum Amplitude of S2 Zipf: 220.0
# Average Amplitude of S1 Sequential: 71.78224687933425
# Average Amplitude of S2 Sequential: 72.18169209431345
# Average Amplitude of S1 Uniform Random: 42.46879334257975
# Average Amplitude of S2 Uniform Random: 42.69278779472954
# Average Amplitude of S1 Zipf: 41.301664355062414
# Average Amplitude of S2 Zipf: 40.25381414701803
# Deviation of S1 Sequential: 0.021662
# Deviation of S2 Sequential: 0.021614
# Deviation of S1 Uniform Random: 0.015481
# Deviation of S2 Uniform Random: 0.015354
# Deviation of S1 Zipf: 0.048802
# Deviation of S2 Zipf: 0.047901
